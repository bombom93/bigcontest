# %% [markdown]
# ## 같은 시간에 방송된 대표product를  exp_min, total, sales를 합쳐서 가져오기
# * 같은 시간에 판매하며, 옵션이 다른 (예를 들면 여성용/남성용, 무이자/일시불, 10인용/6인용)도 하나로 합쳐서 각 각 노출시간 나오게 하기
# * raw data에서 무형, total=0인 data drop 시키지 x

# %%
# !pip install plotly
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from tqdm.notebook import tqdm
# pd.set_option('display.max_rows', 100)

# %%
sum_df
# Out:
#                 broadcast  exp_min  m_code  p_code  \
# 0     2019-01-01 06:00:00     60.0  100346  201072
# 1     2019-01-01 07:00:00     60.0  100305  200974
# 2     2019-01-01 08:00:00     60.0  100808  202377
# 3     2019-01-01 09:00:00     60.0  100816  202404
# 4     2019-01-01 10:00:00     60.0  100809  202395
# ...                   ...      ...     ...     ...
# 6963  2019-12-31 18:20:00     60.0  100356  201134
# 6964  2019-12-31 19:20:00     60.0  100594  201819
# 6965  2019-12-31 20:20:00     60.0  100501  201516
# 6966  2019-12-31 21:20:00     60.0  100155  200556
# 6967  2019-12-31 23:20:00     60.0  100448  201383
#
#                              p_name p_group  unit_price  total_price   sales  \
# 0                     테이트 남성 셀린니트3종      의류       39900   32696000.0   820.0
# 1                  오모떼 레이스 파운데이션 브라      속옷       59000   47878000.0   812.0
# 2     CERINI by PAT 남성 소프트 기모 릴렉스팬츠      의류       59900   99736000.0  1665.0
# 3                       보코 리버시블 무스탕      의류       79000   90973000.0  1151.0
# 4     CERINI by PAT 남성 풀패키지 기모니트 3종      의류       79900  259678000.0  3250.0
# ...                             ...     ...         ...          ...     ...
# 6963                마르엘라로사티 에코무스탕1종      의류       79000  201322000.0  2548.0
# 6964       레스토닉 블루투스 LED 서랍 침대 슈퍼싱글      가구      599000  102360000.0   155.0
# 6965      무이자 국내제조 노비타 뉴스파 비데  무료설치    생활용품      219000  191710000.0   762.0
# 6966            일시불 LG전자 매직스페이스 냉장고      가전     1359000  222022000.0   157.0
# 6967                 무이자쿠첸압력밥솥 10인용      주방      148000  268596000.0  1630.0
#
#       YEAR  ...  MINUTE  SECOND             YEAR_DAY  DAY_NAME  DAY_NUM  \
# 0     2019  ...       0       0  2019-01-01 00:00:00   Tuesday        2
# 1     2019  ...       0       0  2019-01-01 00:00:00   Tuesday        2
# 2     2019  ...       0       0  2019-01-01 00:00:00   Tuesday        2
# 3     2019  ...       0       0  2019-01-01 00:00:00   Tuesday        2
# 4     2019  ...       0       0  2019-01-01 00:00:00   Tuesday        2
# ...    ...  ...     ...     ...                  ...       ...      ...
# 6963  2019  ...      20       0  2019-12-31 00:00:00   Tuesday        2
# 6964  2019  ...      20       0  2019-12-31 00:00:00   Tuesday        2
# 6965  2019  ...      20       0  2019-12-31 00:00:00   Tuesday        2
# 6966  2019  ...      20       0  2019-12-31 00:00:00   Tuesday        2
# 6967  2019  ...      20       0  2019-12-31 00:00:00   Tuesday        2
#
#      p_group_code new_code     no  sales_level  grade
# 0               0     13.0      0            b      4
# 1               1      7.0      6            b      4
# 2               0     16.0      9            d      3
# 3               0     18.0     12            c      3
# 4               0     17.0     15            e      2
# ...           ...      ...    ...          ...    ...
# 6963            0   8745.0  38259            e      2
# 6964           10   8723.0  38262            a      3
# 6965            6   8741.0  38271            b      2
# 6966            5   8725.0  38283            a      2
# 6967            2   8757.0  38292            d      1
#
# [6968 rows x 23 columns]

# %%
df = pd.read_excel('c:/bc/base_line_test.xlsx', header=0) # 무형, total_price가 0인 data 가져오기
df.p_name.loc[15751] = df.p_name.loc[15752]
# 위의 값은 '일시불 올리고 가스와이드그릴 프리미엄형'인데, 해당 방송에서 무이자만 exp_min을 가지고 있으므로 무이자로 바꿔준다.
# Out:
# C:\Users\user\anaconda3\envs\mulcam\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 같은 상품군에 있는 data를 같은 code로 나열하기

# %%
# copy만들어 사용. 왜냐면 후에 df와 merge 해야하므로!
tmp_df= df.copy()

tmp_df['HOUR']= tmp_df['HOUR'].replace(0, 24) # 나중에 for문 - 할 때 , 필요한 부분! 23시 다음 연속된 방송은 0시이기 때문에 오류
tmp_df['HOUR']= tmp_df['HOUR'].replace(1, 25)
tmp_df['HOUR']= tmp_df['HOUR'].replace(2, 26)

tmp_df = tmp_df.dropna(subset=['exp_min']) #없는 값은 있는 값이랑 중복이기에 drop처리/ 있는값은 계속 있다는 idea
# tmp_df

# 같은 날 같은 제품을 팔았을 경우 오류나서 hour 추가
df2 = tmp_df.groupby(['YEAR_DAY','p_group','m_code','p_code','p_name','HOUR']).agg({'exp_min':['sum'],'no':['min']})
df2.sort_index(ascending=False)

df2 = df2.groupby(level=[0,1,2,3,4,5]).sum()
df2.columns = ['exp_min','no'] #나중에 merge하기 편하게 변경
df2 = df2.reset_index() #multiindex라서 

df2['new_code'] = np.arange(0,len(df2.index)) #유일한 값 만들어주고, 번호 매기기

# df2

# hour가 다른 시간이지만, 같은 상품일 때! 그 전 상품이나 뒷 상품이 같은 제품일 경우는 code를 그 전의 값으로 가져옴
for idx in range(1, df2.shape[0]):
    if (df2.loc[idx, 'p_group'] == df2.loc[idx-1, 'p_group']) and (abs(df2.loc[idx, 'p_code'] - df2.loc[idx-1, 'p_code']) <= 1)\
        and (df2.loc[idx, 'p_name'] != df2.loc[idx-1, 'p_name']):
        df2.loc[idx, 'p_name'] = df2.loc[idx-1, 'p_name']
    
    if (df2.loc[idx, 'p_name'] == df2.loc[idx-1,'p_name']) and (abs(df2.loc[idx, 'HOUR'] - df2.loc[idx-1,'HOUR']) <= 1):
        df2.loc[idx, 'new_code'] = df2.loc[idx-1, 'new_code']

# %%
# 같은 날 같은 제품을 팔았을 경우 오류나서 hour 추가
df2 = tmp_df.groupby(['YEAR_DAY','p_group','m_code','p_code','p_name','HOUR']).agg({'exp_min':['sum'],'no':['min']})
df2.sort_index(ascending=False)

df2 = df2.groupby(level=[0,1,2,3,4,5]).sum()
df2.columns = ['exp_min','no'] #나중에 merge하기 편하게 변경
df2 = df2.reset_index() #multiindex라서 

df2['new_code'] = np.arange(0,len(df2.index)) #유일한 값 만들어주고, 번호 매기기

# df2

code_df= pd.merge(left=df, right=df2.iloc[:,[7,8]], how='left', on=['no']) #축소한 데이터와 원래 데이터 merge
# df2에서 생성한 new_code 컬럼을 합쳐주는 작업

code_df['new_code']= code_df['new_code'].fillna(method='ffill') #new_code 를 앞의 값으로 채우기
code_df?

# %%
# df2_2 = df2.copy()

# %%
# hour가 다른 시간이지만, 같은 상품일 때! 그 전 상품이나 뒷 상품이 같은 제품일 경우는 code를 그 전의 값으로 가져옴
for idx in range(1, df2.shape[0]):
    if (df2.loc[idx, 'p_group'] == df2.loc[idx-1, 'p_group']) and (abs(df2.loc[idx, 'p_code'] - df2.loc[idx-1, 'p_code']) <= 1)\
        and (df2.loc[idx, 'p_name'] != df2.loc[idx-1, 'p_name']):
        df2.loc[idx, 'p_name'] = df2.loc[idx-1, 'p_name']
    
    if (df2.loc[idx, 'p_name'] == df2.loc[idx-1,'p_name']) and (abs(df2.loc[idx, 'HOUR'] - df2.loc[idx-1,'HOUR']) <= 1):
        df2.loc[idx, 'new_code'] = df2.loc[idx-1, 'new_code']

# %%
# # hour가 다른 시간이지만, 같은 상품일 때! 그 전 상품이나 뒷 상품이 같은 제품일 경우는 code를 그 전의 값으로 가져옴
# for idx in range(1, df2.shape[0]):
#     if (df2_2.loc[idx, 'p_group'] == df2_2.loc[idx-1, 'p_group']) and (abs(df2_2.loc[idx, 'p_code'] - df2_2.loc[idx-1, 'p_code']) <= 4)\
#         and (df2_2.loc[idx, 'p_name'] != df2_2.loc[idx-1, 'p_name']):
#         df2_2.loc[idx, 'p_name'] = df2_2.loc[idx-1, 'p_name']
    
#     if (df2_2.loc[idx, 'p_name'] == df2_2.loc[idx-1,'p_name']) and (abs(df2_2.loc[idx, 'HOUR'] - df2_2.loc[idx-1,'HOUR']) <= 1):
#         df2_2.loc[idx, 'new_code'] = df2_2.loc[idx-1, 'new_code']

# %%
# df_diff = pd.concat([df2,df2_2]).drop_duplicates(keep=False)

# %%
# pd.options.display.max_rows = None
# df2 == df2_2

# %% [markdown]
# # ------------------------------------------------------------------------------------

# %%
code_df= pd.merge(left=df, right=df2.iloc[:,[7,8]], how='left', on=['no']) #축소한 데이터와 원래 데이터 merge
# df2에서 생성한 new_code 컬럼을 합쳐주는 작업

# %%
code_df['new_code']= code_df['new_code'].fillna(method='ffill') #new_code 를 앞의 값으로 채우기
code_df
# Out:
#                 broadcast    exp_min  m_code  p_code  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00        NaN  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00        NaN  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2019-12-31 00:20:00  20.000000  100073  200196
# 38305 2019-12-31 00:40:00  20.000000  100073  200196
# 38306 2019-12-31 01:00:00  20.000000  100073  200196
# 38307 2019-12-31 01:20:00  20.000000  100490  201478
# 38308 2019-12-31 01:40:00  17.166667  100490  201478
#
#                          p_name p_group  unit_price  total_price  sales  YEAR  \
# 0                 테이트 남성 셀린니트3종      의류       39900    2099000.0   53.0  2019
# 1                 테이트 여성 셀린니트3종      의류       39900    4371000.0  110.0  2019
# 2                 테이트 남성 셀린니트3종      의류       39900    3262000.0   82.0  2019
# 3                 테이트 여성 셀린니트3종      의류       39900    6955000.0  174.0  2019
# 4                 테이트 남성 셀린니트3종      의류       39900    6672000.0  167.0  2019
# ...                         ...     ...         ...          ...    ...   ...
# 38304  삼성화재 행복한파트너 주택화재보험(1912)      무형           0          NaN    NaN  2019
# 38305  삼성화재 행복한파트너 주택화재보험(1912)      무형           0          NaN    NaN  2019
# 38306  삼성화재 행복한파트너 주택화재보험(1912)      무형           0          NaN    NaN  2019
# 38307        더케이 예다함 상조서비스(티포트)      무형           0          NaN    NaN  2019
# 38308        더케이 예다함 상조서비스(티포트)      무형           0          NaN    NaN  2019
#
#        ...  HOUR  MINUTE  SECOND   YEAR_DAY  DAY_NAME DAY_NUM  code  \
# 0      ...     6       0       0 2019-01-01   Tuesday       2     0
# 1      ...     6       0       0 2019-01-01   Tuesday       2     0
# 2      ...     6      20       0 2019-01-01   Tuesday       2     0
# 3      ...     6      20       0 2019-01-01   Tuesday       2     0
# 4      ...     6      40       0 2019-01-01   Tuesday       2     0
# ...    ...   ...     ...     ...        ...       ...     ...   ...
# 38304  ...     0      20       0 2019-12-31   Tuesday       2  7187
# 38305  ...     0      40       0 2019-12-31   Tuesday       2  7187
# 38306  ...     1       0       0 2019-12-31   Tuesday       2  7187
# 38307  ...     1      20       0 2019-12-31   Tuesday       2  7188
# 38308  ...     1      40       0 2019-12-31   Tuesday       2  7188
#
#        p_group_code     no  new_code
# 0                 0      0      13.0
# 1                 0      1      13.0
# 2                 0      2      13.0
# 3                 0      3      13.0
# 4                 0      4      13.0
# ...             ...    ...       ...
# 38304             9  38304    8734.0
# 38305             9  38305    8734.0
# 38306             9  38306    8734.0
# 38307             9  38307    8736.0
# 38308             9  38308    8736.0
#
# [38309 rows x 22 columns]

# %%
# code_df.to_csv('c:/bc/3_whole.csv', encoding='utf-8-sig',index=False)

# %% [markdown]
# ## 데이터 sum하기

# %%
tmp_df = code_df.copy()
df3 = tmp_df.groupby(['new_code']).agg({'exp_min':['sum'],'unit_price':['min'], 'total_price':['sum'],'sales':['sum'],'no':['min']})
df3.columns = ['exp_min','unit_price','total_price','sales','no']
df3.reset_index()

sum_df= pd.merge(code_df.iloc[:,[0,2,3,4,5,9,10,11,12,13,14,15,16,17,19,20,21]],df3,on='no', how='right')
sum_df= sum_df[['broadcast','exp_min','m_code','p_code','p_name','p_group','unit_price','total_price','sales','YEAR','MONTH','DAY','HOUR','MINUTE','SECOND','YEAR_DAY','DAY_NAME','DAY_NUM','p_group_code','new_code','no']]

# sum_df

# %%
# p_group == '무형'을 제거하기 위해서 그 리스트를 가져온다.

mh_list = []
for idx, value in enumerate(sum_df.p_group):
    if value == '무형':
        mh_list.append(idx)
len(mh_list)
# Out:
# 358

# %%
# sum_df[sum_df.p_group == '무형']
sum_df.drop(mh_list, inplace=True)
sum_df.reset_index(drop=True,inplace=True)

# %%
sum_df
# Out:
#                broadcast  exp_min  m_code  p_code  \
# 0    2019-01-01 06:00:00     60.0  100346  201072
# 1    2019-01-01 07:00:00     60.0  100305  200974
# 2    2019-01-01 08:00:00     60.0  100808  202377
# 3    2019-01-01 09:00:00     60.0  100816  202404
# 4    2019-01-01 10:00:00     60.0  100809  202395
# ...                  ...      ...     ...     ...
# 6963 2019-12-31 18:20:00     60.0  100356  201134
# 6964 2019-12-31 19:20:00     60.0  100594  201819
# 6965 2019-12-31 20:20:00     60.0  100501  201516
# 6966 2019-12-31 21:20:00     60.0  100155  200556
# 6967 2019-12-31 23:20:00     60.0  100448  201383
#
#                              p_name p_group  unit_price  total_price   sales  \
# 0                     테이트 남성 셀린니트3종      의류       39900   32696000.0   820.0
# 1                  오모떼 레이스 파운데이션 브라      속옷       59000   47878000.0   812.0
# 2     CERINI by PAT 남성 소프트 기모 릴렉스팬츠      의류       59900   99736000.0  1665.0
# 3                       보코 리버시블 무스탕      의류       79000   90973000.0  1151.0
# 4     CERINI by PAT 남성 풀패키지 기모니트 3종      의류       79900  259678000.0  3250.0
# ...                             ...     ...         ...          ...     ...
# 6963                마르엘라로사티 에코무스탕1종      의류       79000  201322000.0  2548.0
# 6964       레스토닉 블루투스 LED 서랍 침대 슈퍼싱글      가구      599000  102360000.0   155.0
# 6965      무이자 국내제조 노비타 뉴스파 비데  무료설치    생활용품      219000  191710000.0   762.0
# 6966            일시불 LG전자 매직스페이스 냉장고      가전     1359000  222022000.0   157.0
# 6967                 무이자쿠첸압력밥솥 10인용      주방      148000  268596000.0  1630.0
#
#       YEAR  ...  DAY  HOUR  MINUTE  SECOND   YEAR_DAY DAY_NAME DAY_NUM  \
# 0     2019  ...    1     6       0       0 2019-01-01  Tuesday       2
# 1     2019  ...    1     7       0       0 2019-01-01  Tuesday       2
# 2     2019  ...    1     8       0       0 2019-01-01  Tuesday       2
# 3     2019  ...    1     9       0       0 2019-01-01  Tuesday       2
# 4     2019  ...    1    10       0       0 2019-01-01  Tuesday       2
# ...    ...  ...  ...   ...     ...     ...        ...      ...     ...
# 6963  2019  ...   31    18      20       0 2019-12-31  Tuesday       2
# 6964  2019  ...   31    19      20       0 2019-12-31  Tuesday       2
# 6965  2019  ...   31    20      20       0 2019-12-31  Tuesday       2
# 6966  2019  ...   31    21      20       0 2019-12-31  Tuesday       2
# 6967  2019  ...   31    23      20       0 2019-12-31  Tuesday       2
#
#       p_group_code  new_code     no
# 0                0      13.0      0
# 1                1       7.0      6
# 2                0      16.0      9
# 3                0      18.0     12
# 4                0      17.0     15
# ...            ...       ...    ...
# 6963             0    8745.0  38259
# 6964            10    8723.0  38262
# 6965             6    8741.0  38271
# 6966             5    8725.0  38283
# 6967             2    8757.0  38292
#
# [6968 rows x 21 columns]

# %%
# sum_df.to_csv('c:/bc/3_summary.csv', encoding='utf-8-sig',index=False)

# %% [markdown]
# ### 방송단위 병합 후 다음단계 진행 - sales & total_price로 판매량에 대한 평가지표

# %%
sum_df = pd.merge(sum_df,pd.qcut(sum_df.sales,q=5,labels = ['a','b','c','d','e']).to_frame().rename(columns={'sales':'sales_level'}),left_index = True,right_index = True ,how='left')

# %%
fig = px.scatter(sum_df,x="sales",y="total_price",color="sales_level")
fig.show()
# Out:
# <div>                            <div id="ee61460f-ec3c-46c5-b9fd-7cafa50f1559" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
 591.0, 782.0, 791.0, 612.0, 682.0, 655.0, 753.0, 671.0, 703.0, 738.0, 924.0, 747.0, 645.0, 624.0, 616.0, 731.0, 642.0, 954.0, 951.0, 653.0, 589.0, 915.0, 558.0, 757.0, 518.0, 683.0, 826.0, 974.0, 864.0, 552.0, 936.0, 544.0, 724.0, 889.0, 918.0, 619.0, 824.0, 729.0, 833.0, 555.0, 819.0, 547.0, 736.0, 697.0, 806.0, 812.0, 862.0, 924.0, 953.0, 657.0, 758.0, 745.0, 682.0, 537.0, 562.0, 861.0, 937.0, 986.0, 828.0, 867.0, 664.0, 961.0, 904.0, 982.0, 865.0, 982.0, 907.0, 526.0, 910.0, 551.0, 535.0, 668.0, 955.0, 556.0, 798.0, 972.0, 515.0, 529.0, 585.0, 842.0, 806.0, 720.0, 958.0, 891.0, 954.0, 640.0, 946.0, 518.0, 555.0, 679.0, 674.0, 648.0, 923.0, 672.0, 847.0, 949.0, 821.0, 991.0, 754.0, 834.0, 761.0, 948.0, 509.0, 939.0, 595.0, 619.0, 552.0, 955.0, 723.0, 795.0, 973.0, 893.0, 570.0, 921.0, 977.0, 536.0, 558.0, 999.0, 539.0, 703.0, 518.0, 648.0, 785.0, 831.0, 591.0, 596.0, 520.0, 706.0, 606.0, 968.0, 993.0, 970.0, 676.0, 646.0, 916.0, 837.0, 605.0, 919.0, 874.0, 853.0, 730.0, 948.0, 735.0, 848.0, 579.0, 979.0, 724.0, 711.0, 846.0, 766.0, 925.0, 658.0, 798.0, 533.0, 914.0, 958.0, 565.0, 752.0, 606.0, 961.0, 843.0, 635.0, 873.0, 746.0, 790.0, 854.0, 730.0, 791.0, 854.0, 860.0, ...

# %%
sns.boxplot(x='sales_level', y='total_price', data=sum_df)

# %%
def quantile_by_sales(level):

    q0 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 0)
    q1 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 0.25)
    q2 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 0.5)
    q3 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 0.75)
    q4 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 1)
    
    IQR = (q3-q1)
    
    return {'min':q0,'q1':q1,'median':q2,'q3':q3,'max':q4,'iqr':IQR,'upper':q3+(1.5*IQR),'lower':q1-(1.5*IQR), 'mean':sum_df[sum_df['sales_level'] == level].total_price.mean()}

# %%
# sum_df['grade'] = 0
# for row, total_price in enumerate(tqdm(sum_df.total_price)):
#     if total_price >= quantile_by_sales(sum_df.loc[row,'sales_level'])['upper']:
#         sum_df.loc[row,'grade'] = 1
#     elif quantile_by_sales(sum_df.loc[row,'sales_level'])['q3'] <= total_price < quantile_by_sales(sum_df.loc[row,'sales_level'])['upper']:
#         sum_df.loc[row,'grade'] = 2
#     elif quantile_by_sales(sum_df.loc[row,'sales_level'])['q1'] <= total_price < quantile_by_sales(sum_df.loc[row,'sales_level'])['q3']:
#         sum_df.loc[row,'grade'] = 3
#     else:
#         sum_df.loc[row,'grade'] = 4
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6968.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-254-d0fc2313d7a4> in <module>
#       3     if total_price >= quantile_by_sales(sum_df.loc[row,'sales_level'])['upper']:
#       4         sum_df.loc[row,'grade'] = 1
# ----> 5     elif quantile_by_sales(sum_df.loc[row,'sales_level'])['q3'] <= total_price < quantile_by_sales(sum_df.loc[row,'sales_level'])['upper']:
#       6         sum_df.loc[row,'grade'] = 2
#       7     elif quantile_by_sales(sum_df.loc[row,'sales_level'])['q1'] <= total_price < quantile_by_sales(sum_df.loc[row,'sales_level'])['q3']:
#
# <ipython-input-176-aeb9f7b4df22> in quantile_by_sales(level)
#       5     q2 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 0.5)
#       6     q3 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 0.75)
# ----> 7     q4 = np.quantile(sum_df[sum_df['sales_level'] == level].total_price, 1)
#       8
#       9     IQR = (q3-q1)
#
# <__array_function__ internals> in quantile(*args, **kwargs)
#
# ~\anaconda3\envs\mulcam\lib\site-packages\numpy\lib\function_base.py in quantile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3823         raise ValueError("Quantiles must be in the range [0, 1]")
#    3824     return _quantile_unchecked(
# -> 3825         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3826
#    3827
#
# ~\anaconda3\envs\mulcam\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3831     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3832                     overwrite_input=overwrite_input,
# -> 3833                     interpolation=interpolation)
#    3834     if keepdims:
#    3835         return r.reshape(q.shape + k)
#
# ~\anaconda3\envs\mulcam\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3408         keepdim = (1,) * a.ndim
#    3409
# -> 3410     r = func(a, **kwargs)
#    3411     return r, keepdim
#    3412
#
# ~\anaconda3\envs\mulcam\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3923         # Check if the array contains any nan's
#    3924         if np.issubdtype(a.dtype, np.inexact):
# -> 3925             indices_above = concatenate((indices_above, [-1]))
#    3926
#    3927         weights_above = indices - indices_below
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# sum_df.to_csv('c:/bc/sum_df.csv',index=False)

# %%
sum_df = pd.read_csv('c:/bc/sum_df.csv')

# %% [markdown]
# -------------

# %%
# 상품군별로 분포 - 성적 컬럼 구해보기
sum_df
# Out:
#                broadcast  exp_min  m_code  p_code  \
# 0    2019-01-01 06:00:00     60.0  100346  201072
# 1    2019-01-01 07:00:00     60.0  100305  200974
# 2    2019-01-01 08:00:00     60.0  100808  202377
# 3    2019-01-01 09:00:00     60.0  100816  202404
# 4    2019-01-01 10:00:00     60.0  100809  202395
# ...                  ...      ...     ...     ...
# 6963 2019-12-31 18:20:00     60.0  100356  201134
# 6964 2019-12-31 19:20:00     60.0  100594  201819
# 6965 2019-12-31 20:20:00     60.0  100501  201516
# 6966 2019-12-31 21:20:00     60.0  100155  200556
# 6967 2019-12-31 23:20:00     60.0  100448  201383
#
#                              p_name p_group  unit_price  total_price   sales  \
# 0                     테이트 남성 셀린니트3종      의류       39900   32696000.0   820.0
# 1                  오모떼 레이스 파운데이션 브라      속옷       59000   47878000.0   812.0
# 2     CERINI by PAT 남성 소프트 기모 릴렉스팬츠      의류       59900   99736000.0  1665.0
# 3                       보코 리버시블 무스탕      의류       79000   90973000.0  1151.0
# 4     CERINI by PAT 남성 풀패키지 기모니트 3종      의류       79900  259678000.0  3250.0
# ...                             ...     ...         ...          ...     ...
# 6963                마르엘라로사티 에코무스탕1종      의류       79000  201322000.0  2548.0
# 6964       레스토닉 블루투스 LED 서랍 침대 슈퍼싱글      가구      599000  102360000.0   155.0
# 6965      무이자 국내제조 노비타 뉴스파 비데  무료설치    생활용품      219000  191710000.0   762.0
# 6966            일시불 LG전자 매직스페이스 냉장고      가전     1359000  222022000.0   157.0
# 6967                 무이자쿠첸압력밥솥 10인용      주방      148000  268596000.0  1630.0
#
#       YEAR  ...  HOUR  MINUTE  SECOND   YEAR_DAY  DAY_NAME DAY_NUM  \
# 0     2019  ...     6       0       0 2019-01-01   Tuesday       2
# 1     2019  ...     7       0       0 2019-01-01   Tuesday       2
# 2     2019  ...     8       0       0 2019-01-01   Tuesday       2
# 3     2019  ...     9       0       0 2019-01-01   Tuesday       2
# 4     2019  ...    10       0       0 2019-01-01   Tuesday       2
# ...    ...  ...   ...     ...     ...        ...       ...     ...
# 6963  2019  ...    18      20       0 2019-12-31   Tuesday       2
# 6964  2019  ...    19      20       0 2019-12-31   Tuesday       2
# 6965  2019  ...    20      20       0 2019-12-31   Tuesday       2
# 6966  2019  ...    21      20       0 2019-12-31   Tuesday       2
# 6967  2019  ...    23      20       0 2019-12-31   Tuesday       2
#
#      p_group_code  new_code     no  sales_level
# 0               0      13.0      0            b
# 1               1       7.0      6            b
# 2               0      16.0      9            d
# 3               0      18.0     12            c
# 4               0      17.0     15            e
# ...           ...       ...    ...          ...
# 6963            0    8745.0  38259            e
# 6964           10    8723.0  38262            a
# 6965            6    8741.0  38271            b
# 6966            5    8725.0  38283            a
# 6967            2    8757.0  38292            d
#
# [6968 rows x 22 columns]

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
sum_df.p_group.value_counts().plot(kind='bar')

# %%
# sum_df = pd.merge(sum_df,pd.qcut(sum_df.sales,q=5,labels = ['a','b','c','d','e']).to_frame().rename(columns={'sales':'sales_level'}),left_index = True,right_index = True ,how='left')
# 수량 - 가격 그래프 -> 가격과 수량의 관계를 살펴본다.
group_list = sum_df.p_group.unique()
row = 3
col = 4

f, ax = plt.subplots(row,col, figsize=(20,18))
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[0]], ax = ax[0,0])
g.set_title(group_list[0])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[1]], ax = ax[0,1])
g.set_title(group_list[1])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[2]], ax = ax[0,2])
g.set_title(group_list[2])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[3]], ax = ax[0,3])
g.set_title(group_list[3])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[4]], ax = ax[1,0])
g.set_title(group_list[4])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[5]], ax = ax[1,1])
g.set_title(group_list[5])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[6]], ax = ax[1,2])
g.set_title(group_list[6])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[7]], ax = ax[1,3])
g.set_title(group_list[7])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[8]], ax = ax[2,0])
g.set_title(group_list[8])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[9]], ax = ax[2,1])
g.set_title(group_list[9])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df[sum_df['p_group']==group_list[10]], ax = ax[2,2])
g.set_title(group_list[10])
g = sns.lineplot(x='unit_price', y='sales', data = sum_df, ax = ax[2,3])
g.set_title('전체 데이터')
# Out:
# Text(0.5, 1.0, '전체 데이터')

# %%
grade_dict = {}
for i in group_list:
    temp_df = pd.qcut(sum_df[sum_df['p_group']==i].sales, q=5, labels = ['a','b','c','d','e']).to_frame().rename(columns={'sales':'grade_by_group'})
    grade_dict[i] = temp_df
# sum_df = sum_df.rename(columns={'sales_y':'grade_by_group'})

# %%
def scatter_group(group):
    return px.scatter(pd.merge(sum_df, grade_dict[group], left_index=True, right_index=True, how='left')[pd.merge(sum_df, grade_dict[group], left_index=True, right_index=True, how='left')['grade_by_group'].notna()] ,x="sales",y="total_price",color="grade_by_group")

# %%
scatter_group('농수축')
# Out:
# <div>                            <div id="d979f791-42b0-4ddd-99b2-640018a608cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d979f791-42b0-4ddd-99b2-640018a608cf")) {                    Plotly.newPlot(                        "d979f791-42b0-4ddd-99b2-640018a608cf",                        [{"hovertemplate": "grade_by_group=a<br>sales=%{x}<br>total_price=%{y}<extra></extra>", "legendgroup": "a", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "a", "showlegend": true, "type": "scattergl", "x": [1415.0, 1375.0, 1258.0, 1286.0, 1264.0, 1886.0, 1532.0, 1775.0, 1241.0, 1772.0, 1847.0, 1801.0, 1569.0, 1499.0, 1131.0, 1612.0, 1277.0, 1810.0, 1520.0, 1665.0, 1555.0, 778.0, 1271.0, 1323.0, 1552.0, 1105.0, 1668.0, 1395.0, 1127.0, 1358.0, 1327.0, 1580.0, 1249.0, 1444.0, 1740.0, 1078.0, 1449.0, 1006.0, 1171.0, 1691.0, 1043.0, 1463.0, 1688.0, 1070.0, 1355.0, 1313.0, 1232.0, 1410.0, 1455.0, 1123.0, 1624.0, 1404.0, 1464.0, 1769.0, 1788.0, 1706.0, 1413.0, 1698.0, 1449.0, 1833.0, 978.0, 1715.0, 1552.0, 1574.0, 1158.0, 1444.0, 1288.0, 1657.0, 1541.0, 1750.0, 1686.0, 1583.0, 1514.0, 1210.0, 1595.0, 1726.0, 1877.0, 671.0, 1647.0, 1765.0, 1525.0, 1874.0, 1711.0, 724.0, 1841.0, 1867.0, 1619.0, 1088.0, 865.0, 907.0, 1646.0, 806.0, 1502.0, 754.0, 948.0, 1767.0, 676.0, 846.0, 1031.0, 589.0, 978.0, 1740.0, 579.0, 813.0, 785.0, 1579.0, 1692.0, 1544.0, 821.0, 694.0, 796.0, 1743.0, 1544.0, 442.0, 719.0, 1033.0, 980.0, 1661.0, 