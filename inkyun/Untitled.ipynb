# %%
import pickle

with open('c:/bc/low_perform_dict.pickle', 'rb') as f:
    l_lst = pickle.load(f)

# %%
with open('c:/bc/high_perform_dict.pickle', 'rb') as f:
    l_lst = pickle.load(f)
# Out:
# {'의류':                 broadcast    exp_min  m_code  p_code             p_name  \
#  120   2019-01-06 01:00:00  57.100000  100221  200771  도네이 남성 터틀넥 스웨터 4종
#  3246  2019-06-15 01:20:00  33.166667  100416  201318     코몽트 남성 이너티셔츠6종
#  3363  2019-06-22 06:00:00  60.000000  100820  202416    보코 여성 티 블라우스 3종
#  3381  2019-06-22 01:20:00  33.166667  100416  201318     코몽트 남성 이너티셔츠6종
#  5705  2019-10-22 01:00:00  56.683333  100712  202082      젠트웰 남성 니트점퍼세트
#
#       p_group  unit_price  total_price  sales  YEAR  ...  DAY_NUM  \
#  120       의류       49000   28389000.0  581.0  2019  ...        7
#  3246      의류       39900   18391000.0  461.0  2019  ...        6
#  3363      의류       49000   19101000.0  390.0  2019  ...        6
#  3381      의류       39900   17925000.0  449.0  2019  ...        6
#  5705      의류       49000   24502000.0  500.0  2019  ...        2
#
#        p_group_code  new_code     no  sales_level grade season  timeslot  \
# ...
