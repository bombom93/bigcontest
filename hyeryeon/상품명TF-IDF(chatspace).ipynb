# %% [markdown]
# # PyKoSpacing
# * https://github.com/haven-jeon/PyKoSpacing
# * 속도 느림, 공적 텍스트 처리를 더 잘하는 듯

# %%
# !git clone https://github.com/haven-jeon/PyKoSpacing.git
# !pip install ./PyKoSpacing
# Out:
# Cloning into 'PyKoSpacing'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 106 (delta 18), reused 21 (delta 8), pack-reused 71
# Receiving objects: 100% (106/106), 2.25 MiB | 22.79 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# Processing ./PyKoSpacing
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.3-cp36-none-any.whl size=2255638 sha256=e421fa3420ae4ee1d61eda816b191ab8623e3b661413a05d66470f5a3aeda879
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g3gnpj4j/wheels/b7/81/df/67bff2644229510365a49d42a7a61a4ed18db0b8da5091cd1c
# Successfully built pykospacing
# ...

# %% [markdown]
# # ChatSpace
# * https://blog.pingpong.us/spacing/
# * https://github.com/pingpong-ai/chatspace
# * 속도 빠름, 채팅 데이터 특화

# %%
# !git clone https://github.com/pingpong-ai/chatspace.git
# !pip install ./chatspace
# Out:
# Cloning into 'chatspace'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 207 (delta 11), reused 8 (delta 3), pack-reused 173
# Receiving objects: 100% (207/207), 9.15 MiB | 10.60 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# Processing ./chatspace
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 317kB 8.1MB/s
# ...
#   Created wheel for chatspace: filename=chatspace-1.0.2-cp36-none-any.whl size=10669953 sha256=e390b74728673e6692b4d81b4cbce0a669559b2bedb36a774966cd1ad43af31c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ao81ywjd/wheels/ea/b5/37/d03de9763c6d2e1d71c30fee9f14287ea59a747abde5902043
# Successfully built chatspace
# ...

# %% [markdown]
# # TEST

# %%
p_name_test='이경제의 제주바다자연산돔39마리'

# %%
from pykospacing import spacing

spacing(p_name_test)
# Out:
# '이 경제의 제주 바다자연산 돔 39마리'

# %%
from chatspace import ChatSpace

spacer = ChatSpace()
spacer.space(p_name_test)
# Out:
# '이경제의 제주 바다 자연산돔 39마리'

# %% [markdown]
# # 19년 data 불러오기

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import re
# %matplotlib inline
plt.style.use('ggplot') # 그래프에서 격자로 숫자 범위가 눈에 잘 띄도록 ggplot 스타일을 사용
plt.rcParams['font.family'] = 'Malgun Gothic'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
if 'google.colab' in str(get_ipython()):
    print('Running on CoLab')
    df = pd.read_excel('/content/drive/My Drive/빅데이터_콘테스트/base_line.xlsx', header=0, sheet_name='original_data')
else:
    print('Not running on CoLab')
    df = pd.read_excel('c:/bc/base_line.xlsx', header=0, sheet_name='original_data')
# Out:
# Running on CoLab

# %%
temp = df['p_name']

# %%
from tqdm import tqdm_notebook

# %%
cleaned_name_list = []
for name in tqdm_notebook(temp) :
    
        cleaned_name = re.sub('[\(\)\[\]］,\"\/\+&]', ' ', name)

        cleaned_name = re.sub('  ', ' ' , cleaned_name)
        cleaned_name = cleaned_name.strip()
        cleaned_name = cleaned_name.lower()
        cleaned_name = cleaned_name.replace('김치냉장고', '김치 냉장고')
        cleaned_name = cleaned_name.replace('uhdtv', 'uhd tv')
        cleaned_name = re.split('\s+', cleaned_name)

        new_cleand_name = []
        for words in cleaned_name :
            words = words.lower()
            
            if words != '*' and words != 'x':
                new_cleand_name.append(words)
                
        joined = " ".join(new_cleand_name)
        spaced = spacer.space(joined)
  
        cleaned_name_list.append(spaced)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
df['split_p_name'] = cleaned_name_list

# %%
df['split_p_name'] = [ re.sub('[\[\]]', '', str(name)) for name in cleaned_name_list ]

# %%
df.to_excel('chatspace(2019).xlsx')

# %%
if 'google.colab' in str(get_ipython()):
    print('Running on CoLab')
    test = pd.read_excel('/content/drive/My Drive/빅데이터_콘테스트/base_line_eval.xlsx')
else:
    print('Not running on CoLab')
    test = pd.read_excel('/content/drive/My Drive/빅콘테스트/2020 빅콘테스트 데이터분석분야-챔피언리그_2020년 6월 판매실적예측데이터(평가데이터).xlsx', header=0)
# Out:
# Running on CoLab

# %%
temp2 = test['p_name']

# %%
cleaned_name_list = []
for name in tqdm_notebook(temp2) :
    
        cleaned_name = re.sub('[\(\)\[\]］,\"\/\+&]', ' ', name)

        cleaned_name = re.sub('  ', ' ' , cleaned_name)
        cleaned_name = cleaned_name.strip()
        cleaned_name = cleaned_name.lower()
        cleaned_name = cleaned_name.replace('김치냉장고', '김치 냉장고')
        cleaned_name = cleaned_name.replace('uhdtv', 'uhd tv')
        cleaned_name = re.split('\s+', cleaned_name)
        
        new_cleand_name = []
        for words in cleaned_name :
            words = words.lower()
            
            if words != '*' and words != 'x':
                new_cleand_name.append(words)
                
        joined = " ".join(new_cleand_name)
        spaced = spacer.space(joined)

        cleaned_name_list.append(spaced)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
test['split_p_name'] = [ re.sub('[\[\]］]', '', str(name)) for name in cleaned_name_list ]

# %%
test.to_excel('chatspace(2020).xlsx')
