# %%
import pandas as pd
import numpy as np

# %%
weather=pd.read_csv('OBS_ASOS_DD_20200820194530.csv',encoding='CP949')

# %%
weather=weather.iloc[:,2:]

# %%
weather.head()
# Out:
#            일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 0  2019-01-01      -5.0      -8.2      -0.6       NaN         2.1        49.5
# 1  2019-01-02      -4.9      -8.8       0.2       NaN         1.7        42.8
# 2  2019-01-03      -3.5      -8.4       3.2       NaN         1.4        38.8
# 3  2019-01-04      -1.1      -6.2       4.1       NaN         1.2        55.5
# 4  2019-01-05      -2.8      -5.5       1.1       NaN         2.2        40.3
#
#    합계 일조시간(hr)  합계 일사량(MJ/m2)  일 최심적설(cm)
# 0          7.5           7.84         NaN
# 1          8.7          10.48         NaN
# 2          8.7          10.28         NaN
# 3          3.9           6.20         NaN
# 4          8.6          10.05         NaN

# %%
import matplotlib.pyplot as plt

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   일시             31 non-null     object
#  1   평균기온(°C)       31 non-null     float64
#  2   최저기온(°C)       31 non-null     float64
#  3   최고기온(°C)       31 non-null     float64
#  4   일강수량(mm)       5 non-null      float64
#  5   평균 풍속(m/s)     31 non-null     float64
#  6   평균 상대습도(%)     31 non-null     float64
#  7   합계 일조시간(hr)    31 non-null     float64
#  8   합계 일사량(MJ/m2)  31 non-null     float64
#  9   일 최심적설(cm)     0 non-null      float64
# dtypes: float64(9), object(1)
# memory usage: 2.5+ KB

# %%
#korean encoding with visualization
plt.rcParams['font.family'] = 'AppleGothic'
#backend method
# %matplotlib inline

# %%
plt.plot(weather['일시'],weather['평균기온(°C)'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from dataprep.eda import plot

# %%
plot(weather,'평균기온(°C)')
# Out:
#
#
#
#
#
#             <div class="bk-root" id="57e86eee-a9d4-4cb8-ac58-463bdfbb98d7" data-root-id="4337"></div>
#
#
#
#
#
#         <script type="application/json" id="4712">
# ...

# %%
economy=pd.read_csv('경기종합지수.csv',encoding='CP949')

# %%
economy
# Out:
#                          지수별  2019. 01  2019. 02  2019. 03  2019. 04  \
# 0           선행종합지수(2015=100)    114.20    114.40    114.70    115.10
# 1              선행종합지수 전월비(%)      0.20      0.20      0.30      0.30
# 2            재고순환지표(전월차)(%p)     -0.20      0.80      2.10     -0.60
# 3             경제심리지수(전월차)(p)     -1.10      1.10      0.80      2.00
# 4    기계류내수출하지수(선박제외)(전월비)(%)     -1.90     -2.70     -1.50      0.30
# 5              건설수주액(전월비)(%)      7.90     -8.90      3.00     -0.80
# 6            수출입물가비율(전월비)(%)      0.50     -0.60     -1.50     -1.40
# 7                코스피(전월비)(%)     -0.80      2.00      1.40      1.70
# 8            장단기금리차(전월차)(%p)     -0.17     -0.14     -0.01     -0.04
# 9                 선행지수 순환변동치     99.60     99.50     99.50     99.50
# 10            〔순환변동치 전월차〕(p)     -0.10     -0.10      0.00      0.00
# 11             선행지수 전년동월비(%)      1.80      1.70      1.80      1.90
# 12           〔전년동월비 전월차〕(%p)     -0.10     -0.10      0.10      0.10
# ...

# %%
economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   지수별          31 non-null     object
#  1   2019. 01     31 non-null     float64
#  2   2019. 02     31 non-null     float64
#  3   2019. 03     31 non-null     float64
#  4   2019. 04     31 non-null     float64
#  5   2019. 05     31 non-null     float64
#  6   2019. 06     31 non-null     float64
#  7   2019. 07     31 non-null     float64
#  8   2019. 08     31 non-null     float64
#  9   2019. 09     31 non-null     float64
#  10  2019. 10     31 non-null     float64
#  11  2019. 11     31 non-null     float64
#  12  2019. 12     31 non-null     float64
#  13  2020. 01     31 non-null     float64
#  14  2020. 02     31 non-null     float64
#  15  2020. 03     31 non-null     float64
#  16  2020. 04 p)  31 non-null     float64
#  17  2020. 05 p)  31 non-null     float64
# ...

# %%
plt.plot(list(range(1,19)),economy.iloc[0,1:],marker='o')
plt.xticks(list(range(1,19)))
plt.title('jong-hap-ji-su')
# Out:
# Text(0.5, 1.0, 'jong-hap-ji-su')

# %%
ran=list(range(1,19))

# %%
plt.plot(list(range(1,19)),economy.iloc[27,1:],marker='o')
plt.xticks(list(range(1,19)))
plt.title('so-bi-za-mool-ga-ji-su-service')
# Out:
# Text(0.5, 1.0, 'so-bi-za-mool-ga-ji-su-service')
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
life=pd.read_csv('생활물가지수.csv',encoding='CP949')

# %%
life
# Out:
#   시도별            품목별  2019. 01  2019. 02  2019. 03  2019. 04  2019. 05  \
# 0  전국            총지수    104.24    104.69    104.49    104.87    105.05
# 1  전국         생활물가지수    104.03    104.61    104.45    104.81    105.29
# 2  전국             식품    108.79    109.33    108.76    109.29    109.18
# 3  전국          식품 이외    101.49    102.09    102.16    102.43    103.22
# 4  전국            전월세    104.19    104.18    104.14    104.10    104.07
# 5  전국        생활물가 이외    104.53    104.91    104.58    105.10    104.93
# 6  전국  전·월세포함 생활물가지수    104.05    104.55    104.40    104.70    105.10
#
#    2019. 06  2019. 07  2019. 08  2019. 09  2019. 10  2019. 11  2019. 12  \
# 0    104.88    104.56    104.81    105.20    105.46    104.87    105.12
# 1    105.19    104.40    104.73    105.57    105.96    105.37    105.51
# 2    108.76    108.38    109.25    110.69    111.20    109.50    109.59
# 3    103.30    102.29    102.32    102.84    103.16    103.17    103.36
# ...

# %%
plt.plot(list(range(1,19)),life.iloc[2,2:],marker='o')
plt.xticks(list(range(1,19)))
plt.title('food')
# Out:
# Text(0.5, 1.0, 'food')

# %%
plt.plot(list(range(1,19)),life.iloc[1,2:],marker='o')
plt.xticks(list(range(1,19)))
plt.title('saeng-hwal-mool-ga-ji-soo')
# Out:
# Text(0.5, 1.0, 'saeng-hwal-mool-ga-ji-soo')

# %%
record=pd.read_excel('/Users/bomi/PycharmProjects/bigcon/2020_record_0818.xlsx',header=1)

# %%
record.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액  month
# 0  2099000.0      1
# 1  4371000.0      1
# 2  3262000.0      1
# 3  6955000.0      1
# 4  6672000.0      1

# %%
record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38309 entries, 0 to 38308
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   방송일시    38309 non-null  datetime64[ns]
#  1   노출(분)   21525 non-null  float64
#  2   마더코드    38309 non-null  int64
#  3   상품코드    38309 non-null  int64
#  4   상품명     38309 non-null  object
#  5   상품군     38309 non-null  object
#  6   판매단가    38309 non-null  int64
#  7   취급액     35379 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 2.3+ MB

# %%
record['month']=record['방송일시'].dt.month

# %%
grouped=record['취급액'].groupby(record['month'])

# %%
grouped

# %%
sum_g=grouped.sum()
sum_g
# Out:
# month
# 1     6.892150e+10
# 2     5.958138e+10
# 3     6.462860e+10
# 4     6.077887e+10
# 5     6.890008e+10
# 6     6.633750e+10
# 7     6.901510e+10
# 8     6.901195e+10
# 9     6.746911e+10
# 10    6.884348e+10
# 11    7.393539e+10
# 12    7.991718e+10
# Name: 취급액, dtype: float64

# %%
life_jisu=life.iloc[1,2:14]
life_jisu
# Out:
# 2019. 01    104.03
# 2019. 02    104.61
# 2019. 03    104.45
# 2019. 04    104.81
# 2019. 05    105.29
# 2019. 06    105.19
# 2019. 07     104.4
# 2019. 08    104.73
# 2019. 09    105.57
# 2019. 10    105.96
# 2019. 11    105.37
# 2019. 12    105.51
# Name: 1, dtype: object

# %%
import seaborn as sns

# %%
plt.plot()
# Out:
# []

# %%
relation=pd.DataFrame({'date':life_jisu.index, 'life_jisu':life_jisu.values})

# %%
relation['total_amount']=pd.DataFrame({'total_amount':sum_g.values})
relation
# Out:
#         date life_jisu  total_amount
# 0   2019. 01    104.03  6.892150e+10
# 1   2019. 02    104.61  5.958138e+10
# 2   2019. 03    104.45  6.462860e+10
# 3   2019. 04    104.81  6.077887e+10
# 4   2019. 05    105.29  6.890008e+10
# 5   2019. 06    105.19  6.633750e+10
# 6   2019. 07     104.4  6.901510e+10
# 7   2019. 08    104.73  6.901195e+10
# 8   2019. 09    105.57  6.746911e+10
# 9   2019. 10    105.96  6.884348e+10
# 10  2019. 11    105.37  7.393539e+10
# 11  2019. 12    105.51  7.991718e+10

# %%
from dataprep.eda import plot,plot_correlation

# %%
relation['weather']=pd.DataFrame({'weather':})
# Out:
#   File "<ipython-input-111-2e8baad35e76>", line 1
#     relation['weather']=pd.DataFrame({'weather':})
#                                                 ^
# SyntaxError: invalid syntax

# %%
df= pd.read_csv('/Users/bomi/Downloads/retail_sale_chart.csv',encoding='CP949')

# %%
df.head()
# Out:
#     업태별 2019. 01 2019. 01.1 2019. 01.2 2019. 02 2019. 02.1 2019. 02.2  \
# 0   업태별     경상지수       불변지수     계절조정지수     경상지수       불변지수     계절조정지수
# 1   총지수    111.7      109.8      110.9    101.9       99.8      111.1
# 2   백화점      102       98.7      101.3     94.3         91       98.4
# 3  대형마트    108.7        103       96.2       94       88.5       94.2
# 4   면세점    223.3      227.1        218    227.2      230.4      262.3
#
#   2019. 03 2019. 03.1 2019. 03.2  ... 2020. 03.2 2020. 04 2020. 04.1  \
# 0     경상지수       불변지수     계절조정지수  ...     계절조정지수     경상지수       불변지수
# 1    118.1        116      113.9  ...      104.8    110.8      108.9
# 2    110.9      107.3      102.4  ...       65.8     84.9       82.3
# 3    100.9       95.8       95.3  ...       90.5       95       88.6
# 4    282.5      285.4      269.7  ...      136.6    128.7      133.6
#
#   2020. 04.2 2020. 05 p) 2020. 05 p).1 2020. 05 p).2 2020. 06 p)  \
# ...

# %%
#경상지수homeshopping
a=df.iloc[19,:37]
home=[]
for i in range(1,37,3):
    home.append(a[i])
home
# Out:
# ['142.2',
#  '116.1',
#  '137',
#  '133.5',
#  '137.1',
#  '125.8',
#  '127.2',
#  '123.1',
#  '127.6',
#  '143',
#  '142',
#  '141.8']

# %%
relation['current']=home

# %%
relation
#life_jisu:생활물가지수
#total_amount:취급액 월별 합산
#current: 경상지수
# Out:
#         date life_jisu  total_amount current
# 0   2019. 01    104.03  6.892150e+10   142.2
# 1   2019. 02    104.61  5.958138e+10   116.1
# 2   2019. 03    104.45  6.462860e+10     137
# 3   2019. 04    104.81  6.077887e+10   133.5
# 4   2019. 05    105.29  6.890008e+10   137.1
# 5   2019. 06    105.19  6.633750e+10   125.8
# 6   2019. 07     104.4  6.901510e+10   127.2
# 7   2019. 08    104.73  6.901195e+10   123.1
# 8   2019. 09    105.57  6.746911e+10   127.6
# 9   2019. 10    105.96  6.884348e+10     143
# 10  2019. 11    105.37  7.393539e+10     142
# 11  2019. 12    105.51  7.991718e+10   141.8

# %%
relation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   total_amount  12 non-null     float64
#  1   current       12 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 320.0+ bytes

# %%
for_corr=relation.iloc[:,1:]
for_corr
# Out:
#    life_jisu  total_amount current
# 0     104.03  6.892150e+10   142.2
# 1     104.61  5.958138e+10   116.1
# 2     104.45  6.462860e+10     137
# 3     104.81  6.077887e+10   133.5
# 4     105.29  6.890008e+10   137.1
# 5     105.19  6.633750e+10   125.8
# 6      104.4  6.901510e+10   127.2
# 7     104.73  6.901195e+10   123.1
# 8     105.57  6.746911e+10   127.6
# 9     105.96  6.884348e+10     143
# 10    105.37  7.393539e+10     142
# 11    105.51  7.991718e+10   141.8

# %%
sns.heatmap(for_corr.astype(float).corr(), linewidths = 0.1, vmax = 1.0, square = True, linecolor = "white", annot = True, annot_kws = {"size" : 16})

# %%
month_weather=pd.read_csv('/Users/bomi/Downloads/서울부산월별날씨.csv',encoding='CP949')

# %%
month_weather=month_weather.fillna(0)

# %%
seoul_m_weather=month_weather.iloc[:12,3:]

# %%
seoul_m_weather
# Out:
#     평균기온(°C)  최고기온(°C)  최저기온(°C)  평균상대습도(%)  일최다강수량(mm)  평균풍속(m/s)  일조율(%)  \
# 0       -0.9       8.5     -10.1         46         0.0        1.8   70.01
# 1        1.0      14.5     -10.2         47        16.0        1.8   62.98
# 2        7.1      17.6      -1.7         51        16.5        2.1   54.99
# 3       12.1      28.2       0.3         51        17.4        1.9   56.13
# 4       19.4      33.4       8.4         47        22.0        2.1   71.40
# 5       22.5      32.8      14.1         61        35.3        1.7   53.18
# 6       25.9      36.1      19.3         69        62.3        1.8   33.44
# 7       27.2      36.8      18.5         69        56.2        1.6   58.59
# 8       22.6      30.5      13.6         65        63.2        2.2   45.22
# 9       16.4      28.2       4.7         62        25.4        2.1   67.80
# 10       7.6      22.1      -4.6         56        21.1        2.2   66.45
# ...

# %%
busan_m_weather=month_weather.iloc[12:,3:]
busan_m_weather
# Out:
#     평균기온(°C)  최고기온(°C)  최저기온(°C)  평균상대습도(%)  일최다강수량(mm)  평균풍속(m/s)  일조율(%)  \
# 12       4.5      13.7      -4.4         39        11.3        3.1   76.76
# 13       6.6      16.5      -4.2         50        28.8        2.9   66.05
# 14      10.5      21.0       0.5         54        33.7        3.6   69.00
# 15      13.4      23.4       2.1         60        25.3        3.2   53.72
# 16      19.3      30.1      11.0         58        37.1        3.3   69.62
# 17      21.1      29.7      15.5         74       112.5        2.6   54.10
# 18      24.3      30.9      19.8         85       172.2        3.7   43.49
# 19      27.0      35.0      20.3         78        72.5        3.1   57.37
# 20      23.1      30.5      15.8         82        81.6        2.8   42.34
# 21      18.6      28.8      10.4         67        94.8        3.0   64.16
# 22      13.0      24.0       2.0         58         6.8        2.7   69.55
# ...

# %%
relation_w=pd.concat([for_corr,seoul_m_weather],axis=1)
relation_w
# Out:
#    life_jisu  total_amount current  평균기온(°C)  최고기온(°C)  최저기온(°C)  평균상대습도(%)  \
# 0     104.03  6.892150e+10   142.2      -0.9       8.5     -10.1         46
# 1     104.61  5.958138e+10   116.1       1.0      14.5     -10.2         47
# 2     104.45  6.462860e+10     137       7.1      17.6      -1.7         51
# 3     104.81  6.077887e+10   133.5      12.1      28.2       0.3         51
# 4     105.29  6.890008e+10   137.1      19.4      33.4       8.4         47
# 5     105.19  6.633750e+10   125.8      22.5      32.8      14.1         61
# 6      104.4  6.901510e+10   127.2      25.9      36.1      19.3         69
# 7     104.73  6.901195e+10   123.1      27.2      36.8      18.5         69
# 8     105.57  6.746911e+10   127.6      22.6      30.5      13.6         65
# 9     105.96  6.884348e+10     143      16.4      28.2       4.7         62
# 10    105.37  7.393539e+10     142       7.6      22.1      -4.6         56
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(relation_w.astype(float).corr(), linewidths = 0.1, vmax = 1.0, square = True, linecolor = "white", annot = True, annot_kws = {"size" : 16})
