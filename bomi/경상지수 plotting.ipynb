# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/bomi/Downloads/홈쇼핑 경상지수 분기별.csv',encoding='CP949')

# %%
df
# Out:
#    업종별 2015 1/4 2015 2/4 2015 3/4 2015 4/4 2016 1/4 2016 2/4 2016 3/4  \
# 0  업종별     경상지수     경상지수     경상지수     경상지수     경상지수     경상지수     경상지수
# 1  홈쇼핑     99.0     95.9     93.5    111.6    105.7    108.3    106.6
#
#   2016 4/4 2017 1/4  ... 2018 1/4 2018 2/4 2018 3/4 2018 4/4 2019 1/4  \
# 0     경상지수     경상지수  ...     경상지수     경상지수     경상지수     경상지수     경상지수
# 1    122.2    113.6  ...    129.4    129.1    121.5    140.4    131.8
#
#   2019 2/4 2019 3/4 2019 4/4 2020 1/4 2020 2/4 p)
# 0     경상지수     경상지수     경상지수     경상지수        경상지수
# 1    132.1    126.0    142.3    140.6       141.8
#
# [2 rows x 23 columns]

# %%
dft=df.T
dft
# Out:
#                 0      1
# 업종별           업종별    홈쇼핑
# 2015 1/4     경상지수   99.0
# 2015 2/4     경상지수   95.9
# 2015 3/4     경상지수   93.5
# 2015 4/4     경상지수  111.6
# 2016 1/4     경상지수  105.7
# 2016 2/4     경상지수  108.3
# 2016 3/4     경상지수  106.6
# 2016 4/4     경상지수  122.2
# 2017 1/4     경상지수  113.6
# 2017 2/4     경상지수  114.4
# 2017 3/4     경상지수  114.0
# 2017 4/4     경상지수  129.8
# 2018 1/4     경상지수  129.4
# 2018 2/4     경상지수  129.1
# 2018 3/4     경상지수  121.5
# 2018 4/4     경상지수  140.4
# 2019 1/4     경상지수  131.8
# 2019 2/4     경상지수  132.1
# 2019 3/4     경상지수  126.0
# 2019 4/4     경상지수  142.3
# 2020 1/4     경상지수  140.6
# 2020 2/4 p)  경상지수  141.8

# %%
dft.iloc[0,-1]
# Out:
# '홈쇼핑'

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
del dft['0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-8438087d7f7d> in <module>
# ----> 1 del dft['0']
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __delitem__(self, key)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 업종별 to 2020 2/4 p)
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       23 non-null     object
#  1   1       23 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
dft.columns=['date','jisu']

# %%
dft
# Out:
#              date   jisu
# 업종별           업종별    홈쇼핑
# 2015 1/4     경상지수   99.0
# 2015 2/4     경상지수   95.9
# 2015 3/4     경상지수   93.5
# 2015 4/4     경상지수  111.6
# 2016 1/4     경상지수  105.7
# 2016 2/4     경상지수  108.3
# 2016 3/4     경상지수  106.6
# 2016 4/4     경상지수  122.2
# 2017 1/4     경상지수  113.6
# 2017 2/4     경상지수  114.4
# 2017 3/4     경상지수  114.0
# 2017 4/4     경상지수  129.8
# 2018 1/4     경상지수  129.4
# 2018 2/4     경상지수  129.1
# 2018 3/4     경상지수  121.5
# 2018 4/4     경상지수  140.4
# 2019 1/4     경상지수  131.8
# 2019 2/4     경상지수  132.1
# 2019 3/4     경상지수  126.0
# 2019 4/4     경상지수  142.3
# 2020 1/4     경상지수  140.6
# 2020 2/4 p)  경상지수  141.8

# %%
del dft['date']

# %%
dft
# Out:
#               jisu
# 업종별            홈쇼핑
# 2015 1/4      99.0
# 2015 2/4      95.9
# 2015 3/4      93.5
# 2015 4/4     111.6
# 2016 1/4     105.7
# 2016 2/4     108.3
# 2016 3/4     106.6
# 2016 4/4     122.2
# 2017 1/4     113.6
# 2017 2/4     114.4
# 2017 3/4     114.0
# 2017 4/4     129.8
# 2018 1/4     129.4
# 2018 2/4     129.1
# 2018 3/4     121.5
# 2018 4/4     140.4
# 2019 1/4     131.8
# 2019 2/4     132.1
# 2019 3/4     126.0
# 2019 4/4     142.3
# 2020 1/4     140.6
# 2020 2/4 p)  141.8

# %%
dft=dft.iloc[1:,:]

# %%
dft['jisu']=dft['jisu'].apply(lambda x: float(x))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
jisu=df.iloc[1:,-1]

# %%
dft.reset_index(inplace=True)

# %%
dft.columns=['date','jisu']

# %%
sns.plot(x='date',y='jisu',data=dft)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-71a9ed486213> in <module>
# ----> 1 sns.plot(x='date',y='jisu',data=dft)
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
dft.iloc[-1,0]='2020 2/4'
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dft
# Out:
#         date   jisu
# 0   2015 1/4   99.0
# 1   2015 2/4   95.9
# 2   2015 3/4   93.5
# 3   2015 4/4  111.6
# 4   2016 1/4  105.7
# 5   2016 2/4  108.3
# 6   2016 3/4  106.6
# 7   2016 4/4  122.2
# 8   2017 1/4  113.6
# 9   2017 2/4  114.4
# 10  2017 3/4  114.0
# 11  2017 4/4  129.8
# 12  2018 1/4  129.4
# 13  2018 2/4  129.1
# 14  2018 3/4  121.5
# 15  2018 4/4  140.4
# 16  2019 1/4  131.8
# 17  2019 2/4  132.1
# 18  2019 3/4  126.0
# 19  2019 4/4  142.3
# 20  2020 1/4  140.6
# 21  2020 2/4  141.8

# %%
dft['date']=dft['date'].apply(lambda x: pd.to_datetime(x))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dft
# Out:
#          date   jisu
# 0  2015-01-04   99.0
# 1  2015-02-04   95.9
# 2  2015-03-04   93.5
# 3  2015-04-04  111.6
# 4  2016-01-04  105.7
# 5  2016-02-04  108.3
# 6  2016-03-04  106.6
# 7  2016-04-04  122.2
# 8  2017-01-04  113.6
# 9  2017-02-04  114.4
# 10 2017-03-04  114.0
# 11 2017-04-04  129.8
# 12 2018-01-04  129.4
# 13 2018-02-04  129.1
# 14 2018-03-04  121.5
# 15 2018-04-04  140.4
# 16 2019-01-04  131.8
# 17 2019-02-04  132.1
# 18 2019-03-04  126.0
# 19 2019-04-04  142.3
# 20 2020-01-04  140.6
# 21 2020-02-04  141.8

# %%
dft['jisu'].plot()
