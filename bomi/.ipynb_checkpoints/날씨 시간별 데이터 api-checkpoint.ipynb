# %%
import pandas as pd
import seaborn as sns
from dataprep.eda import *
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] = 'AppleGothic'
# Out:
# NumExpr defaulting to 8 threads.

# %% [markdown]
# base line 불러오기

# %%
df=pd.read_excel('/Users/bomi/bc/base_line.xlsx')

# %%
df.head()
# Out:
#             broadcast  exp_min  m_code  p_code         p_name p_group  \
# 0 2019-01-01 06:00:00     20.0  100346  201072  테이트 남성 셀린니트3종      의류
# 1 2019-01-01 06:00:00      NaN  100346  201079  테이트 여성 셀린니트3종      의류
# 2 2019-01-01 06:20:00     20.0  100346  201072  테이트 남성 셀린니트3종      의류
# 3 2019-01-01 06:20:00      NaN  100346  201079  테이트 여성 셀린니트3종      의류
# 4 2019-01-01 06:40:00     20.0  100346  201072  테이트 남성 셀린니트3종      의류
#
#    unit_price  total_price  sales  YEAR  MONTH  DAY  HOUR  MINUTE  SECOND  \
# 0       39900      2099000     53  2019      1    1     6       0       0
# 1       39900      4371000    110  2019      1    1     6       0       0
# 2       39900      3262000     82  2019      1    1     6      20       0
# 3       39900      6955000    174  2019      1    1     6      20       0
# 4       39900      6672000    167  2019      1    1     6      40       0
#
#     YEAR_DAY DAY_NAME  DAY_NUM  code  no
# 0 2019-01-01  Tuesday        2     0   0
# 1 2019-01-01  Tuesday        2     0   1
# 2 2019-01-01  Tuesday        2     0   2
# 3 2019-01-01  Tuesday        2     0   3
# 4 2019-01-01  Tuesday        2     0   4

# %% [markdown]
# 추가 데이터 불러오기 :
# 기상청01_지상(종관,ASOS)시간자료_조회서비스_오픈API from 공공데이터포털

# %%
we=pd.read_csv('/Users/bomi/bc/weather.csv',encoding='CP949')

# %%
we
# Out:
#        지점                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0     108  2019-01-01 00:00    -5.5      NaN      1.0     290.0   54.0
# 1     108  2019-01-01 01:00    -5.9      NaN      1.8     270.0   56.0
# 2     108  2019-01-01 02:00    -6.5      NaN      1.2     290.0   60.0
# 3     108  2019-01-01 03:00    -6.9      NaN      2.2     270.0   62.0
# 4     108  2019-01-01 04:00    -7.2      NaN      1.2     270.0   57.0
# ...   ...               ...     ...      ...      ...       ...    ...
# 8755  108  2019-12-31 19:00    -6.9      NaN      1.7     290.0   38.0
# 8756  108  2019-12-31 20:00    -7.0      NaN      2.9     290.0   41.0
# 8757  108  2019-12-31 21:00    -7.4      NaN      0.8      20.0   43.0
# 8758  108  2019-12-31 22:00    -8.2      NaN      0.0       0.0   42.0
# 8759  108  2019-12-31 23:00    -7.4      NaN      0.0       0.0   45.0
#
#       증기압(hPa)  이슬점온도(°C)  현지기압(hPa)  ...  운형(운형약어)  최저운고(100m )  시정(10m)  \
# 0          2.2      -13.3     1024.1  ...       NaN          NaN     1573
# 1          2.2      -13.2     1024.0  ...       NaN          NaN     1569
# 2          2.3      -12.9     1024.2  ...       NaN          NaN     1462
# 3          2.3      -12.9     1024.3  ...        Ci          NaN     1281
# 4          2.0      -14.2     1023.9  ...        Ci          NaN     1195
# ...        ...        ...        ...  ...       ...          ...      ...
# 8755       1.4      -18.8     1024.1  ...       NaN          NaN     1981
# 8756       1.5      -18.0     1024.1  ...       NaN          NaN     1912
# 8757       1.5      -17.8     1023.9  ...       NaN          NaN     1993
# 8758       1.4      -18.8     1023.3  ...       NaN          NaN     1990
# 8759       1.6      -17.3     1022.9  ...       NaN         14.0     2000
#
#       지면상태(지면상태코드)  현상번호(국내식)  지면온도(°C)  5cm 지중온도(°C) 10cm 지중온도(°C)  \
# 0              NaN        NaN      -6.0          -3.4          -1.1
# 1              NaN        NaN      -6.5          -3.9          -1.4
# 2              NaN        NaN      -7.1          -4.2          -1.6
# 3              NaN        NaN      -7.3          -4.6          -1.8
# 4              NaN        NaN      -7.5          -4.7          -2.0
# ...            ...        ...       ...           ...           ...
# 8755           NaN        NaN      -3.6          -0.6           0.9
# 8756           NaN        NaN      -4.1          -0.7           0.9
# 8757           NaN        NaN      -4.4          -0.8           0.9
# 8758           NaN        NaN      -4.6          -1.0           0.8
# 8759           NaN        NaN      -3.5          -1.1           0.8
#
#       20cm 지중온도(°C)  30cm 지중온도(°C)
# 0               0.0            1.0
# 1               0.0            1.0
# 2               0.0            1.0
# 3               0.0            1.0
# 4              -0.1            1.0
# ...             ...            ...
# 8755            2.3            3.3
# 8756            2.3            3.3
# 8757            2.3            3.3
# 8758            2.2            3.2
# 8759            2.2            3.2
#
# [8760 rows x 27 columns]

# %%
del we['지점']

# %%
we
# Out:
#                     일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  \
# 0     2019-01-01 00:00    -5.5      NaN      1.0     290.0   54.0       2.2
# 1     2019-01-01 01:00    -5.9      NaN      1.8     270.0   56.0       2.2
# 2     2019-01-01 02:00    -6.5      NaN      1.2     290.0   60.0       2.3
# 3     2019-01-01 03:00    -6.9      NaN      2.2     270.0   62.0       2.3
# 4     2019-01-01 04:00    -7.2      NaN      1.2     270.0   57.0       2.0
# ...                ...     ...      ...      ...       ...    ...       ...
# 8755  2019-12-31 19:00    -6.9      NaN      1.7     290.0   38.0       1.4
# 8756  2019-12-31 20:00    -7.0      NaN      2.9     290.0   41.0       1.5
# 8757  2019-12-31 21:00    -7.4      NaN      0.8      20.0   43.0       1.5
# 8758  2019-12-31 22:00    -8.2      NaN      0.0       0.0   42.0       1.4
# 8759  2019-12-31 23:00    -7.4      NaN      0.0       0.0   45.0       1.6
#
#       이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  ...  운형(운형약어)  최저운고(100m )  시정(10m)  \
# 0         -13.3     1024.1     1035.3  ...       NaN          NaN     1573
# 1         -13.2     1024.0     1035.2  ...       NaN          NaN     1569
# 2         -12.9     1024.2     1035.5  ...       NaN          NaN     1462
# 3         -12.9     1024.3     1035.6  ...        Ci          NaN     1281
# 4         -14.2     1023.9     1035.2  ...        Ci          NaN     1195
# ...         ...        ...        ...  ...       ...          ...      ...
# 8755      -18.8     1024.1     1035.4  ...       NaN          NaN     1981
# 8756      -18.0     1024.1     1035.4  ...       NaN          NaN     1912
# 8757      -17.8     1023.9     1035.2  ...       NaN          NaN     1993
# 8758      -18.8     1023.3     1034.6  ...       NaN          NaN     1990
# 8759      -17.3     1022.9     1034.2  ...       NaN         14.0     2000
#
#       지면상태(지면상태코드)  현상번호(국내식)  지면온도(°C) 5cm 지중온도(°C)  10cm 지중온도(°C)  \
# 0              NaN        NaN      -6.0         -3.4           -1.1
# 1              NaN        NaN      -6.5         -3.9           -1.4
# 2              NaN        NaN      -7.1         -4.2           -1.6
# 3              NaN        NaN      -7.3         -4.6           -1.8
# 4              NaN        NaN      -7.5         -4.7           -2.0
# ...            ...        ...       ...          ...            ...
# 8755           NaN        NaN      -3.6         -0.6            0.9
# 8756           NaN        NaN      -4.1         -0.7            0.9
# 8757           NaN        NaN      -4.4         -0.8            0.9
# 8758           NaN        NaN      -4.6         -1.0            0.8
# 8759           NaN        NaN      -3.5         -1.1            0.8
#
#       20cm 지중온도(°C)  30cm 지중온도(°C)
# 0               0.0            1.0
# 1               0.0            1.0
# 2               0.0            1.0
# 3               0.0            1.0
# 4              -0.1            1.0
# ...             ...            ...
# 8755            2.3            3.3
# 8756            2.3            3.3
# 8757            2.3            3.3
# 8758            2.2            3.2
# 8759            2.2            3.2
#
# [8760 rows x 26 columns]

# %%
we.columns
# Out:
# Index(['일시', '기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)', '증기압(hPa)',
#        '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '적설(cm)',
#        '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )',
#        '시정(10m)', '지면상태(지면상태코드)', '현상번호(국내식)', '지면온도(°C)', '5cm 지중온도(°C)',
#        '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
import requests
from bs4 import BeautifulSoup

# %%
soup_list=[]
for i in range(1,20):
    key='JIhQPZFK66iLNy5Sft4JFuU3LvLtZByKmwbu2ac5h7jFG86WGaV6uhmfHoXhQz%2FHl3Ttr7NlYA%2FxlKT1IyHdKg%3D%3D'
    url='http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList?serviceKey={}'.format(key)
    params={'numOfRows':'500',
            'pageNo':i,
            'dataCd':'ASOS',
            'dataType':'JSON',
            'dateCd':'HR',
            'stnIds':'108',
            'endDt':'20200101',
            'endHh':'02',
            'startHh':'06',
            'startDt':'20190101'}
    resp=requests.get(url,params=params).content

# %%
key='JIhQPZFK66iLNy5Sft4JFuU3LvLtZByKmwbu2ac5h7jFG86WGaV6uhmfHoXhQz%2FHl3Ttr7NlYA%2FxlKT1IyHdKg%3D%3D'
url='http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList?serviceKey={}'.format(key)
params={'numOfRows':'10',
        'pageNo': '1',
        'dataCd':'ASOS',
        'dataType':'JSON',
        'dateCd':'HR',
        'stnIds':'108',
        'endDt':'20200101',
        'endHh':'02',
        'startHh':'06',
        'startDt':'20190101'}
resp=requests.get(url,params=params).content

# %%
json_object= json.loads(resp)

# %%
json_object
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'tm': '2019-01-01 06:00',
#       'rnum': '1',
#       'stnId': '108',
#       'ta': -7.9,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 1.3,
#       'wsQcflg': '',
#       'wd': 290,
#       'wdQcflg': '',
#       'hm': 60,
#       'hmQcflg': '0',
#       'pv': 2.0,
#       'td': -14.3,
#       'pa': 1023.6,
#       'paQcflg': '0',
#       'ps': 1034.9,
#       'psQcflg': '0',
#       'ss': 0.0,
#       'ssQcflg': '9',
#       'icsr': 0.0,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 4,
#       'dc10LmcsCa': 0,
#       'clfmAbbrCd': 'Ci',
#       'lcsCh': 0,
#       'vs': 1232,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': -8.0,
#       'tsQcflg': '0',
#       'm005Te': -5.2,
#       'm01Te': -2.3,
#       'm02Te': -0.1,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 07:00',
#       'rnum': '2',
#       'stnId': '108',
#       'ta': -7.7,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 1.3,
#       'wsQcflg': '',
#       'wd': 320,
#       'wdQcflg': '',
#       'hm': 58,
#       'hmQcflg': '0',
#       'pv': 2.0,
#       'td': -14.5,
#       'pa': 1023.1,
#       'paQcflg': '0',
#       'ps': 1034.4,
#       'psQcflg': '0',
#       'ss': 0.0,
#       'ssQcflg': '9',
#       'icsr': 0.0,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 6,
#       'dc10LmcsCa': 0,
#       'clfmAbbrCd': 'Ci',
#       'lcsCh': 0,
#       'vs': 1473,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': -8.1,
#       'tsQcflg': '0',
#       'm005Te': -5.3,
#       'm01Te': -2.4,
#       'm02Te': -0.1,
#       'm03Te': 1.0,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 08:00',
#       'rnum': '3',
#       'stnId': '108',
#       'ta': -7.7,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 0.9,
#       'wsQcflg': '',
#       'wd': 360,
#       'wdQcflg': '',
#       'hm': 57,
#       'hmQcflg': '0',
#       'pv': 2.0,
#       'td': -14.7,
#       'pa': 1023.0,
#       'paQcflg': '0',
#       'ps': 1034.3,
#       'psQcflg': '0',
#       'ss': 0.0,
#       'ssQcflg': '',
#       'icsr': 0.0,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 8,
#       'dc10LmcsCa': 8,
#       'clfmAbbrCd': 'Ac',
#       'lcsCh': 41,
#       'vs': 1652,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': -7.8,
#       'tsQcflg': '0',
#       'm005Te': -5.2,
#       'm01Te': -2.5,
#       'm02Te': -0.2,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 09:00',
#       'rnum': '4',
#       'stnId': '108',
#       'ta': -7.0,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 0.9,
#       'wsQcflg': '',
#       'wd': 290,
#       'wdQcflg': '',
#       'hm': 50,
#       'hmQcflg': '0',
#       'pv': 1.8,
#       'td': -15.6,
#       'pa': 1023.2,
#       'paQcflg': '0',
#       'ps': 1034.5,
#       'psQcflg': '0',
#       'ss': 0.0,
#       'ssQcflg': '',
#       'icsr': 0.17,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 9,
#       'dc10LmcsCa': 9,
#       'clfmAbbrCd': 'Ac',
#       'lcsCh': 35,
#       'vs': 1770,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': -5.2,
#       'tsQcflg': '0',
#       'm005Te': -4.7,
#       'm01Te': -2.4,
#       'm02Te': -0.1,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 10:00',
#       'rnum': '5',
#       'stnId': '108',
#       'ta': -4.9,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 1.6,
#       'wsQcflg': '',
#       'wd': 290,
#       'wdQcflg': '',
#       'hm': 44,
#       'hmQcflg': '0',
#       'pv': 1.9,
#       'td': -15.3,
#       'pa': 1023.3,
#       'paQcflg': '0',
#       'ps': 1034.5,
#       'psQcflg': '0',
#       'ss': 0.6,
#       'ssQcflg': '',
#       'icsr': 0.69,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 8,
#       'dc10LmcsCa': 4,
#       'clfmAbbrCd': 'AcCi',
#       'lcsCh': 29,
#       'vs': 1588,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': -1.4,
#       'tsQcflg': '0',
#       'm005Te': -3.3,
#       'm01Te': -2.3,
#       'm02Te': -0.2,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 11:00',
#       'rnum': '6',
#       'stnId': '108',
#       'ta': -3.7,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 2.5,
#       'wsQcflg': '',
#       'wd': 290,
#       'wdQcflg': '',
#       'hm': 41,
#       'hmQcflg': '0',
#       'pv': 1.9,
#       'td': -15.0,
#       'pa': 1023.0,
#       'paQcflg': '0',
#       'ps': 1034.1,
#       'psQcflg': '0',
#       'ss': 1.0,
#       'ssQcflg': '',
#       'icsr': 1.25,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 5,
#       'dc10LmcsCa': 1,
#       'clfmAbbrCd': 'ScAc',
#       'lcsCh': 10,
#       'vs': 1653,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': 1.3,
#       'tsQcflg': '0',
#       'm005Te': -1.8,
#       'm01Te': -1.8,
#       'm02Te': -0.2,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 12:00',
#       'rnum': '7',
#       'stnId': '108',
#       'ta': -2.8,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 2.8,
#       'wsQcflg': '',
#       'wd': 290,
#       'wdQcflg': '',
#       'hm': 47,
#       'hmQcflg': '0',
#       'pv': 2.3,
#       'td': -12.5,
#       'pa': 1022.0,
#       'paQcflg': '0',
#       'ps': 1033.1,
#       'psQcflg': '0',
#       'ss': 1.0,
#       'ssQcflg': '',
#       'icsr': 1.41,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 8,
#       'dc10LmcsCa': 8,
#       'clfmAbbrCd': 'Sc',
#       'lcsCh': 9,
#       'vs': 1640,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': 2.8,
#       'tsQcflg': '0',
#       'm005Te': -1.1,
#       'm01Te': -1.4,
#       'm02Te': -0.2,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 13:00',
#       'rnum': '8',
#       'stnId': '108',
#       'ta': -1.5,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 2.7,
#       'wsQcflg': '',
#       'wd': 270,
#       'wdQcflg': '',
#       'hm': 49,
#       'hmQcflg': '0',
#       'pv': 2.7,
#       'td': -10.8,
#       'pa': 1020.9,
#       'paQcflg': '0',
#       'ps': 1031.9,
#       'psQcflg': '0',
#       'ss': 1.0,
#       'ssQcflg': '',
#       'icsr': 1.42,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 7,
#       'dc10LmcsCa': 7,
#       'clfmAbbrCd': 'Sc',
#       'lcsCh': 9,
#       'vs': 1213,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': 5.1,
#       'tsQcflg': '0',
#       'm005Te': -0.6,
#       'm01Te': -1.1,
#       'm02Te': -0.2,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 14:00',
#       'rnum': '9',
#       'stnId': '108',
#       'ta': -1.7,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 3.5,
#       'wsQcflg': '',
#       'wd': 290,
#       'wdQcflg': '',
#       'hm': 51,
#       'hmQcflg': '0',
#       'pv': 2.8,
#       'td': -10.5,
#       'pa': 1020.4,
#       'paQcflg': '0',
#       'ps': 1031.4,
#       'psQcflg': '0',
#       'ss': 1.0,
#       'ssQcflg': '',
#       'icsr': 1.08,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 8,
#       'dc10LmcsCa': 8,
#       'clfmAbbrCd': 'Sc',
#       'lcsCh': 9,
#       'vs': 1286,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': 3.1,
#       'tsQcflg': '0',
#       'm005Te': -0.3,
#       'm01Te': -0.8,
#       'm02Te': -0.1,
#       'm03Te': 0.9,
#       'stnNm': '서울'},
#      {'tm': '2019-01-01 15:00',
#       'rnum': '10',
#       'stnId': '108',
#       'ta': -1.5,
#       'taQcflg': '0',
#       'rn': 0.0,
#       'rnQcflg': '',
#       'ws': 3.0,
#       'wsQcflg': '',
#       'wd': 270,
#       'wdQcflg': '',
#       'hm': 46,
#       'hmQcflg': '0',
#       'pv': 2.5,
#       'td': -11.6,
#       'pa': 1020.7,
#       'paQcflg': '0',
#       'ps': 1031.7,
#       'psQcflg': '0',
#       'ss': 0.8,
#       'ssQcflg': '',
#       'icsr': 0.66,
#       'dsnw': 0.0,
#       'hr3Fhsc': 0.0,
#       'dc10Tca': 4,
#       'dc10LmcsCa': 3,
#       'clfmAbbrCd': 'ScCi',
#       'lcsCh': 10,
#       'vs': 1549,
#       'gndSttCd': 0,
#       'dmstMtphNo': '',
#       'ts': 1.2,
#       'tsQcflg': '0',
#       'm005Te': -0.2,
#       'm01Te': -0.7,
#       'm02Te': -0.1,
#       'm03Te': 0.8,
#       'stnNm': '서울'}]},
#    'pageNo': 1,
#    'numOfRows': 10,
#    'totalCount': 8757}}}

# %%
json_item=json_object['response']['body']['items']['item']

# %%
json_item
# Out:
# [{'tm': '2019-01-01 06:00',
#   'rnum': '1',
#   'stnId': '108',
#   'ta': -7.9,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 1.3,
#   'wsQcflg': '',
#   'wd': 290,
#   'wdQcflg': '',
#   'hm': 60,
#   'hmQcflg': '0',
#   'pv': 2.0,
#   'td': -14.3,
#   'pa': 1023.6,
#   'paQcflg': '0',
#   'ps': 1034.9,
#   'psQcflg': '0',
#   'ss': 0.0,
#   'ssQcflg': '9',
#   'icsr': 0.0,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 4,
#   'dc10LmcsCa': 0,
#   'clfmAbbrCd': 'Ci',
#   'lcsCh': 0,
#   'vs': 1232,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': -8.0,
#   'tsQcflg': '0',
#   'm005Te': -5.2,
#   'm01Te': -2.3,
#   'm02Te': -0.1,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 07:00',
#   'rnum': '2',
#   'stnId': '108',
#   'ta': -7.7,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 1.3,
#   'wsQcflg': '',
#   'wd': 320,
#   'wdQcflg': '',
#   'hm': 58,
#   'hmQcflg': '0',
#   'pv': 2.0,
#   'td': -14.5,
#   'pa': 1023.1,
#   'paQcflg': '0',
#   'ps': 1034.4,
#   'psQcflg': '0',
#   'ss': 0.0,
#   'ssQcflg': '9',
#   'icsr': 0.0,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 6,
#   'dc10LmcsCa': 0,
#   'clfmAbbrCd': 'Ci',
#   'lcsCh': 0,
#   'vs': 1473,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': -8.1,
#   'tsQcflg': '0',
#   'm005Te': -5.3,
#   'm01Te': -2.4,
#   'm02Te': -0.1,
#   'm03Te': 1.0,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 08:00',
#   'rnum': '3',
#   'stnId': '108',
#   'ta': -7.7,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 0.9,
#   'wsQcflg': '',
#   'wd': 360,
#   'wdQcflg': '',
#   'hm': 57,
#   'hmQcflg': '0',
#   'pv': 2.0,
#   'td': -14.7,
#   'pa': 1023.0,
#   'paQcflg': '0',
#   'ps': 1034.3,
#   'psQcflg': '0',
#   'ss': 0.0,
#   'ssQcflg': '',
#   'icsr': 0.0,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 8,
#   'dc10LmcsCa': 8,
#   'clfmAbbrCd': 'Ac',
#   'lcsCh': 41,
#   'vs': 1652,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': -7.8,
#   'tsQcflg': '0',
#   'm005Te': -5.2,
#   'm01Te': -2.5,
#   'm02Te': -0.2,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 09:00',
#   'rnum': '4',
#   'stnId': '108',
#   'ta': -7.0,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 0.9,
#   'wsQcflg': '',
#   'wd': 290,
#   'wdQcflg': '',
#   'hm': 50,
#   'hmQcflg': '0',
#   'pv': 1.8,
#   'td': -15.6,
#   'pa': 1023.2,
#   'paQcflg': '0',
#   'ps': 1034.5,
#   'psQcflg': '0',
#   'ss': 0.0,
#   'ssQcflg': '',
#   'icsr': 0.17,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 9,
#   'dc10LmcsCa': 9,
#   'clfmAbbrCd': 'Ac',
#   'lcsCh': 35,
#   'vs': 1770,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': -5.2,
#   'tsQcflg': '0',
#   'm005Te': -4.7,
#   'm01Te': -2.4,
#   'm02Te': -0.1,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 10:00',
#   'rnum': '5',
#   'stnId': '108',
#   'ta': -4.9,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 1.6,
#   'wsQcflg': '',
#   'wd': 290,
#   'wdQcflg': '',
#   'hm': 44,
#   'hmQcflg': '0',
#   'pv': 1.9,
#   'td': -15.3,
#   'pa': 1023.3,
#   'paQcflg': '0',
#   'ps': 1034.5,
#   'psQcflg': '0',
#   'ss': 0.6,
#   'ssQcflg': '',
#   'icsr': 0.69,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 8,
#   'dc10LmcsCa': 4,
#   'clfmAbbrCd': 'AcCi',
#   'lcsCh': 29,
#   'vs': 1588,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': -1.4,
#   'tsQcflg': '0',
#   'm005Te': -3.3,
#   'm01Te': -2.3,
#   'm02Te': -0.2,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 11:00',
#   'rnum': '6',
#   'stnId': '108',
#   'ta': -3.7,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 2.5,
#   'wsQcflg': '',
#   'wd': 290,
#   'wdQcflg': '',
#   'hm': 41,
#   'hmQcflg': '0',
#   'pv': 1.9,
#   'td': -15.0,
#   'pa': 1023.0,
#   'paQcflg': '0',
#   'ps': 1034.1,
#   'psQcflg': '0',
#   'ss': 1.0,
#   'ssQcflg': '',
#   'icsr': 1.25,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 5,
#   'dc10LmcsCa': 1,
#   'clfmAbbrCd': 'ScAc',
#   'lcsCh': 10,
#   'vs': 1653,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': 1.3,
#   'tsQcflg': '0',
#   'm005Te': -1.8,
#   'm01Te': -1.8,
#   'm02Te': -0.2,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 12:00',
#   'rnum': '7',
#   'stnId': '108',
#   'ta': -2.8,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 2.8,
#   'wsQcflg': '',
#   'wd': 290,
#   'wdQcflg': '',
#   'hm': 47,
#   'hmQcflg': '0',
#   'pv': 2.3,
#   'td': -12.5,
#   'pa': 1022.0,
#   'paQcflg': '0',
#   'ps': 1033.1,
#   'psQcflg': '0',
#   'ss': 1.0,
#   'ssQcflg': '',
#   'icsr': 1.41,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 8,
#   'dc10LmcsCa': 8,
#   'clfmAbbrCd': 'Sc',
#   'lcsCh': 9,
#   'vs': 1640,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': 2.8,
#   'tsQcflg': '0',
#   'm005Te': -1.1,
#   'm01Te': -1.4,
#   'm02Te': -0.2,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 13:00',
#   'rnum': '8',
#   'stnId': '108',
#   'ta': -1.5,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 2.7,
#   'wsQcflg': '',
#   'wd': 270,
#   'wdQcflg': '',
#   'hm': 49,
#   'hmQcflg': '0',
#   'pv': 2.7,
#   'td': -10.8,
#   'pa': 1020.9,
#   'paQcflg': '0',
#   'ps': 1031.9,
#   'psQcflg': '0',
#   'ss': 1.0,
#   'ssQcflg': '',
#   'icsr': 1.42,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 7,
#   'dc10LmcsCa': 7,
#   'clfmAbbrCd': 'Sc',
#   'lcsCh': 9,
#   'vs': 1213,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': 5.1,
#   'tsQcflg': '0',
#   'm005Te': -0.6,
#   'm01Te': -1.1,
#   'm02Te': -0.2,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 14:00',
#   'rnum': '9',
#   'stnId': '108',
#   'ta': -1.7,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 3.5,
#   'wsQcflg': '',
#   'wd': 290,
#   'wdQcflg': '',
#   'hm': 51,
#   'hmQcflg': '0',
#   'pv': 2.8,
#   'td': -10.5,
#   'pa': 1020.4,
#   'paQcflg': '0',
#   'ps': 1031.4,
#   'psQcflg': '0',
#   'ss': 1.0,
#   'ssQcflg': '',
#   'icsr': 1.08,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 8,
#   'dc10LmcsCa': 8,
#   'clfmAbbrCd': 'Sc',
#   'lcsCh': 9,
#   'vs': 1286,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': 3.1,
#   'tsQcflg': '0',
#   'm005Te': -0.3,
#   'm01Te': -0.8,
#   'm02Te': -0.1,
#   'm03Te': 0.9,
#   'stnNm': '서울'},
#  {'tm': '2019-01-01 15:00',
#   'rnum': '10',
#   'stnId': '108',
#   'ta': -1.5,
#   'taQcflg': '0',
#   'rn': 0.0,
#   'rnQcflg': '',
#   'ws': 3.0,
#   'wsQcflg': '',
#   'wd': 270,
#   'wdQcflg': '',
#   'hm': 46,
#   'hmQcflg': '0',
#   'pv': 2.5,
#   'td': -11.6,
#   'pa': 1020.7,
#   'paQcflg': '0',
#   'ps': 1031.7,
#   'psQcflg': '0',
#   'ss': 0.8,
#   'ssQcflg': '',
#   'icsr': 0.66,
#   'dsnw': 0.0,
#   'hr3Fhsc': 0.0,
#   'dc10Tca': 4,
#   'dc10LmcsCa': 3,
#   'clfmAbbrCd': 'ScCi',
#   'lcsCh': 10,
#   'vs': 1549,
#   'gndSttCd': 0,
#   'dmstMtphNo': '',
#   'ts': 1.2,
#   'tsQcflg': '0',
#   'm005Te': -0.2,
#   'm01Te': -0.7,
#   'm02Te': -0.1,
#   'm03Te': 0.8,
#   'stnNm': '서울'}]

# %%
folen(json_item)
# Out:
# 10
